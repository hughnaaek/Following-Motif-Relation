# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
from tqdm.notebook import trange as tnrange

# %%
from dtw import *
# Out:
# Importing the dtw module. When using in academic works please cite:
#   T. Giorgino. Computing and Visualizing Dynamic Time Warping Alignments in R: The dtw Package.
#   J. Stat. Soft., doi:10.18637/jss.v031.i07.

# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join('..')))

from util.visualization import *
from util.preprocessing import *
from util.evaluation import *
from following_motif_relation.compared_method import *
from following_motif_relation.followingMotif import *
from dataset.syntheticDataset import *

# %% [markdown]
# # Dataset

# %% [markdown]
# ## Dataset 1 : Single Motif

# %%
leader_list_1   = [leading_ts(randseed=i,k_motif=1,varied_len=False,one_motif=True) for i in range(1000)]
follower_list_1 = [following_ts(leader_list_1[i],randseed= i,uncontinuous=False,one_motif=True)    for i in range(1000)]

# %%
for i in range(3): 
    leadfollow_visualization(leader_list_1[i][0],follower_list_1[i][0])

# %% [markdown]
# ## Dataset 2 : Continuous Following

# %%
leader_list_2   = [leading_ts(randseed=i,k_motif=10,varied_len=False,one_motif=False)            for i in range(1000)]
follower_list_2 = [following_ts(leader_list_2[i],randseed= i,uncontinuous=False,one_motif=False) for i in range(1000)]

# %%
for i in range(3): 
    leadfollow_visualization(leader_list_2[i][0],follower_list_2[i][0])

# %% [markdown]
# ## Dataset 3 : Noncontinuous Following

# %%
leader_list_3   = [leading_ts(randseed=i,k_motif=10,varied_len=False,one_motif=False)           for i in range(1000)]
follower_list_3 = [following_ts(leader_list_3[i],randseed= i,uncontinuous=True,one_motif=False) for i in range(1000)]

# %%
for i in range(3):
    leadfollow_visualization(leader_list_3[i][0],follower_list_3[i][0])

# %% [markdown]
# # Experiment 1: Performance of methods for determining which time series leads or follows

# %% [markdown]
# ## 1. Computing results with Following Motif Method, Maximum Correlation, and FLICA

# %%
# 1.Motif Following Method 

# p aabbreviated from positive
p_result_motif1 = [following_motif_method(leader_list_1[i][0],follower_list_1[i][0],randseed=i)[0] for i in tnrange(1000)] 
p_result_motif2 = [following_motif_method(leader_list_2[i][0],follower_list_2[i][0],randseed=i)[0] for i in tnrange(1000)] 
p_result_motif3 = [following_motif_method(leader_list_3[i][0],follower_list_3[i][0],randseed=i)[0] for i in tnrange(1000)] 

# n aabbreviated from negative
n_result_motif1 = [following_motif_method(follower_list_1[i][0],leader_list_1[i][0],randseed=i)[0] for i in tnrange(1000)] 
n_result_motif2 = [following_motif_method(follower_list_2[i][0],leader_list_2[i][0],randseed=i)[0] for i in tnrange(1000)] 
n_result_motif3 = [following_motif_method(follower_list_3[i][0],leader_list_3[i][0],randseed=i)[0] for i in tnrange(1000)]
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
# 2.FLICA

# p aabbreviated from positive
p_result_FLICA1 = [FLICA(leader_list_1[i][0],follower_list_1[i][0]) for i in tnrange(1000)] 
p_result_FLICA2 = [FLICA(leader_list_2[i][0],follower_list_2[i][0]) for i in tnrange(1000)] 
p_result_FLICA3 = [FLICA(leader_list_3[i][0],follower_list_3[i][0]) for i in tnrange(1000)]

# n aabbreviated from negative
n_result_FLICA1 = [FLICA(follower_list_1[i][0],leader_list_1[i][0]) for i in tnrange(1000)] 
n_result_FLICA2 = [FLICA(follower_list_2[i][0],leader_list_2[i][0]) for i in tnrange(1000)] 
n_result_FLICA3 = [FLICA(follower_list_3[i][0],leader_list_3[i][0]) for i in tnrange(1000)]
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
# 3.Cross Correlation

# p aabbreviated from positive
p_result_max_correlation1 = [max_correlation(leader_list_1[i][0],follower_list_1[i][0]) for i in tnrange(1000)] 
p_result_max_correlation2 = [max_correlation(leader_list_2[i][0],follower_list_2[i][0]) for i in tnrange(1000)] 
p_result_max_correlation3 = [max_correlation(leader_list_3[i][0],follower_list_3[i][0]) for i in tnrange(1000)] 

# n aabbreviated from negative
n_result_max_correlation1 = [max_correlation(follower_list_1[i][0],leader_list_1[i][0]) for i in tnrange(1000)] 
n_result_max_correlation2 = [max_correlation(follower_list_2[i][0],leader_list_2[i][0]) for i in tnrange(1000)] 
n_result_max_correlation3 = [max_correlation(follower_list_3[i][0],leader_list_3[i][0]) for i in tnrange(1000)]
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# ## 2. Confusion Matrix for each method

# %%
from sklearn.metrics import confusion_matrix

n_dataset = 1000

y_true = np.hstack([[True]*n_dataset,[False]*n_dataset])

y_pred_result_motif1 = np.hstack([p_result_motif1[:n_dataset],n_result_motif1[:n_dataset]])
y_pred_result_motif2 = np.hstack([p_result_motif2[:n_dataset],n_result_motif2[:n_dataset]])
y_pred_result_motif3 = np.hstack([p_result_motif3[:n_dataset],n_result_motif3[:n_dataset]])

cm_result_motif1 = confusion_matrix(y_true, y_pred_result_motif1)
cm_result_motif2 = confusion_matrix(y_true, y_pred_result_motif2)
cm_result_motif3 = confusion_matrix(y_true, y_pred_result_motif3)

#=======================================================================================

y_pred_result_FLICA1 = np.hstack([p_result_FLICA1[:n_dataset],n_result_FLICA1[:n_dataset]])
y_pred_result_FLICA2 = np.hstack([p_result_FLICA2[:n_dataset],n_result_FLICA2[:n_dataset]])
y_pred_result_FLICA3 = np.hstack([p_result_FLICA3[:n_dataset],n_result_FLICA3[:n_dataset]])

cm_result_FLICA1 = confusion_matrix(y_true, y_pred_result_FLICA1)
cm_result_FLICA2 = confusion_matrix(y_true, y_pred_result_FLICA2)
cm_result_FLICA3 = confusion_matrix(y_true, y_pred_result_FLICA3)

#=======================================================================================

y_pred_result_max_correlation1 = np.hstack([p_result_max_correlation1[:n_dataset],n_result_max_correlation1[:n_dataset]])
y_pred_result_max_correlation2 = np.hstack([p_result_max_correlation2[:n_dataset],n_result_max_correlation2[:n_dataset]])
y_pred_result_max_correlation3 = np.hstack([p_result_max_correlation3[:n_dataset],n_result_max_correlation3[:n_dataset]])

cm_result_max_correlation1 = confusion_matrix(y_true, y_pred_result_max_correlation1)
cm_result_max_correlation2 = confusion_matrix(y_true, y_pred_result_max_correlation2)
cm_result_max_correlation3 = confusion_matrix(y_true, y_pred_result_max_correlation3)

# %%
data = [
    calculate_matrix(*sklearn_cm_extract(cm_result_motif1)),
    calculate_matrix(*sklearn_cm_extract(cm_result_motif2)),
    calculate_matrix(*sklearn_cm_extract(cm_result_motif3)),
    calculate_matrix(*(sklearn_cm_extract(cm_result_motif1+cm_result_motif2+cm_result_motif3)))
]

# Create DataFrame
df = pd.DataFrame(data, columns=['TP', 'TN', 'FP', 'FN','Precision','Recall','F1','Accuracy'])
"""
df.index = [
    "motif and discord fixed length",
    "motif and discord varied length",
    "motif and discord varied length with uncontinous"
]
"""
df.index = ["Dataset1","Dataset2","Dataset3","Dataset1+2+3"]
df
# Out:
#                 TP    TN  FP  FN  Precision    Recall        F1  Accuracy
# Dataset1       996   996   4   4   0.996000  0.996000  0.996000     0.996
# Dataset2      1000  1000   0   0   1.000000  1.000000  1.000000     1.000
# Dataset3       985   987  13  15   0.986974  0.985000  0.985986     0.986
# Dataset1+2+3  2981  2983  17  19   0.994330  0.993667  0.993998     0.994

# %%
data = [
    calculate_matrix(*sklearn_cm_extract(cm_result_FLICA1)),
    calculate_matrix(*sklearn_cm_extract(cm_result_FLICA2)),
    calculate_matrix(*sklearn_cm_extract(cm_result_FLICA3)),
    calculate_matrix(*(sklearn_cm_extract(cm_result_FLICA1+cm_result_FLICA2+cm_result_FLICA3)))
]

df = pd.DataFrame(data, columns=['TP', 'TN', 'FP', 'FN','Precision','Recall','F1','Accuracy'])
"""
df.index = [
    "motif and discord fixed length",
    "motif and discord varied length",
    "motif and discord varied length with uncontinous"
]
"""
df.index = ["Dataset1","Dataset2","Dataset3","Dataset1+2+3"]
df
# Out:
#                 TP    TN   FP   FN  Precision    Recall        F1  Accuracy
# Dataset1       707   709  291  293   0.708417  0.707000  0.707708     0.708
# Dataset2       732   732  268  268   0.732000  0.732000  0.732000     0.732
# Dataset3       663   663  337  337   0.663000  0.663000  0.663000     0.663
# Dataset1+2+3  2102  2104  896  898   0.701134  0.700667  0.700900     0.701

# %%
data = [
    calculate_matrix(*sklearn_cm_extract(cm_result_max_correlation1)),
    calculate_matrix(*sklearn_cm_extract(cm_result_max_correlation2)),
    calculate_matrix(*sklearn_cm_extract(cm_result_max_correlation3)),
    calculate_matrix(*(sklearn_cm_extract(cm_result_max_correlation1+cm_result_max_correlation2+cm_result_max_correlation3)))
]

df = pd.DataFrame(data, columns=['TP', 'TN', 'FP', 'FN','Precision','Recall','F1','Accuracy'])
"""
df.index = [
    "motif and discord fixed length",
    "motif and discord varied length",
    "motif and discord varied length with uncontinous"
]
"""
df.index = ["Dataset1","Dataset2","Dataset3","Dataset1+2+3"]
df
# Out:
#                 TP    TN   FP   FN  Precision    Recall        F1  Accuracy
# Dataset1       989  1000    0   11   1.000000  0.989000  0.994470  0.994500
# Dataset2       872   872  128  128   0.872000  0.872000  0.872000  0.872000
# Dataset3       684   684  316  316   0.684000  0.684000  0.684000  0.684000
# Dataset1+2+3  2545  2556  444  455   0.851455  0.848333  0.849891  0.850167

# %% [markdown]
# # Experiment 2: Performance of Following Motif Method for inferring time steps of following motifs task

# %%
result_dataset1 = np.array([0,0,0,0])
for i in tnrange(1000):
    result_dataset1 += evaluate_a_pair_ts(leader_list_1[i],follower_list_1[i],wd=30,thres=30,randseed=0,verbose=False)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
result_dataset2 = np.array([0,0,0,0])
for i in tnrange(1000):
    result_dataset2 += evaluate_a_pair_ts(leader_list_2[i],follower_list_2[i],wd=30,thres=30,randseed=0,verbose=False)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
data = [
    calculate_matrix(result_dataset1[0],result_dataset1[1],result_dataset1[2],result_dataset1[3]),
    calculate_matrix(result_dataset2[0],result_dataset2[1],result_dataset2[2],result_dataset2[3]),
    calculate_matrix(result_dataset1[0]+result_dataset2[0],
                     result_dataset1[1]+result_dataset2[1],
                     result_dataset1[2]+result_dataset2[2],
                     result_dataset1[3]+result_dataset2[3]),
]

# Create DataFrame
df = pd.DataFrame(data, columns=['TP', 'TN', 'FP', 'FN','Precision','Recall','F1','Accuracy'])
df.index = ["Dataset1","Dataset2","Dataset1+2"]
df
# Out:
#                 TP      TN     FP     FN  Precision    Recall        F1  \
# Dataset1    151346  212139  41521      0   0.784717  1.000000  0.879374
# Dataset2    231541  255956  51541  67375   0.817929  0.774602  0.795676
# Dataset1+2  382887  468095  93062  67375   0.804471  0.850365  0.826781
#
#             Accuracy
# Dataset1    0.897481
# Dataset2    0.803903
# Dataset1+2  0.841374

# %% [markdown]
# # Case Study: Simple alignment of following relation interval in synthetic data

# %%
i = 883
print(fr"random seed: {i}")
np.random.seed(i)

leading_signal   = (leader_list_2[i][0]).copy()
following_signal = (follower_list_2[i][0]).copy()

result = following_motif_method(leading_signal,following_signal,wd=50,thres=10,randseed=i)

leadfollow_visualization(leading_signal[result[2][1]],following_signal[result[2][0]])
# Out:
# random seed: 883

# %%
alignment_plot(leading_signal,following_signal,result)
# Out:
# Standard Length: 380

# %%
alignment = dtw(leading_signal,
    following_signal,
    keep_internals=True, 
    step_pattern=rabinerJuangStepPattern(6, "c"))

alignment.plot(type="twoway",offset=-15)
# Out:
# <AxesSubplot:xlabel='Index', ylabel='Query value'>
